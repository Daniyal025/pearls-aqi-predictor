# %% [markdown]
# # EDA — Pearls AQI Predictor
# Loads features from MongoDB and explores AQI + pollutant patterns.
# Run AFTER backfill so there is data to explore.

# %%
import sys
sys.path.insert(0, '../src')
import pandas as pd
from aqi_predictor.database import collections as C
from aqi_predictor.database.mongodb_client import get_db
df = pd.DataFrame(list(get_db()[C.AQI_FEATURES].find()))
print(df.shape)
df.head()

# %%
df['aqi'].value_counts().sort_index()

# %%
df[['pm2_5','pm10','o3','no2']].describe()
